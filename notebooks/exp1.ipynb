# %%
import os
import sys


main_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if main_dir not in sys.path:
    sys.path.insert(0, main_dir)
from src.common import analysis

# YOUR OWN DATA 
# results_folder = "001_inference_with_global_transformations"
# results_path = os.path.abspath(os.path.join(os.getcwd(), "..", os.path.join("data", "results", "exp1", results_folder)))

# PRE-GENERATED DATA
results_path = os.path.abspath(os.path.join(os.getcwd(), "..", os.path.join("data", "results", "pre_generated_results", "exp1_paper")))

figures_folder = os.path.abspath(os.path.join(os.getcwd(), "..", os.path.join("data", "figures")))

df = analysis.load_exp1_data(results_path)

analysis.proper_args_print(analysis.load_exp_args(results_path))

analysis.generate_figure_exp1(df, analysis.load_exp_args(results_path), figures_folder)
# Out:
# actions : [0, 1, 2, 3, 4]
# camera_side_size : 10
# experiment_name : global_inference_with_unknown_transformations
# image_env_path : data/environments/NatWdwF.jpeg
# nb_iter_inference : 10000
# nb_iter_metric : 10000
# output_dir : data/results/exp1/001_inference_with_global_transformations
# seed : 100
# snr : 40
# transformations : [0, 1, 2, 3, 4, 5, 6, 7, 8]
# verbose : True
