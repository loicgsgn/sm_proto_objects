# %%
import os
import sys

main_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if main_dir not in sys.path:
    sys.path.insert(0, main_dir)

from src.common import analysis

# YOUR OWN DATA 
# results_folder = "002_inference_environment_vs_object"
# results_path = os.path.abspath(os.path.join(os.getcwd(), "..", os.path.join("data", "results", "exp2", results_folder)))

# PRE-GENERATED DATA
results_path = os.path.abspath(os.path.join(os.getcwd(), "..", os.path.join("data", "results", "pre_generated_results", "exp2_paper")))

figures_folder = os.path.abspath(os.path.join(os.getcwd(), "..", os.path.join("data", "figures")))

df = analysis.load_exp2_data(results_path)

analysis.proper_args_print(analysis.load_exp_args(results_path))

analysis.generate_figure_exp2(df, figures_folder, show_indiv_accuracies=False)
# Out:
# actions : [0, 1, 2, 3, 4]
# camera_side_size : 10
# image_env_path : data/environments/NatWdwF.jpeg
# nb_iter_inference_per_object : 100
# nb_iter_metric : 10000
# nb_seeds : 100
# snr_array : [0, 10, 20, 30, 40, 60]
# transformations : [0, 1, 2, 3, 4]
# verbose : True
